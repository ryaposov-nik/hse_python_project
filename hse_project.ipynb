# %% [markdown]
# <a href="https://colab.research.google.com/github/ryaposov-nik/hse_python_project/blob/main/hse_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, world!')
# Out:
# Hello, world!
